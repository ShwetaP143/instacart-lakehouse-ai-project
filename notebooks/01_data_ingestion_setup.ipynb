# %%
# %pip install kaggle

# %%
dbutils.library.restartPython()

# %%
dbutils.fs.ls("/Volumes/main/default/instacart_vol/")

# %%
# Define volume raw path
raw_volume_path = "/Volumes/main/default/instacart_vol/instacart/raw"

# Create raw directory if not exists
dbutils.fs.mkdirs(raw_volume_path)

# Download dataset directly into Volume
# !kaggle datasets download -d psparks/instacart-market-basket-analysis -p /Volumes/main/default/instacart_vol/instacart/raw

print("✅ Dataset downloaded directly into Volume")

# %%
import zipfile
import os

zip_path = "/Volumes/main/default/instacart_vol/instacart/raw/instacart-market-basket-analysis.zip"
extract_path = "/Volumes/main/default/instacart_vol/instacart/raw"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Dataset extracted inside Volume")

# %%
dbutils.fs.ls("/Volumes/main/default/instacart_vol/instacart/raw/")

# %%
# Databricks notebook source
# ============================================
# Project: Instacart Lakehouse AI Project
# Layer: Data Ingestion
# Description: Download and land raw dataset into Unity Catalog Volume
# Author: Shweta Pawar
# ============================================

# COMMAND ----------

# Define raw landing path in Unity Catalog Volume
raw_volume_path = "/Volumes/main/default/instacart_vol/instacart/raw"

dbutils.fs.mkdirs(raw_volume_path)

print("Raw landing path ready:", raw_volume_path)

# COMMAND ----------

# Download dataset directly into Volume
# !kaggle datasets download -d psparks/instacart-market-basket-analysis -p /Volumes/main/default/instacart_vol/instacart/raw

print("Dataset downloaded into Volume")

# COMMAND ----------

# Extract ZIP inside Volume
import zipfile

zip_path = "/Volumes/main/default/instacart_vol/instacart/raw/instacart-market-basket-analysis.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(raw_volume_path)

print("Dataset extracted successfully into Volume")
